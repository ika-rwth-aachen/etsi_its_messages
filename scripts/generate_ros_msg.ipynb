# %%
from glob import glob

import asn1tools

# %%
files = glob("../**/*.asn", recursive=True)

def parseFiles(files):
  return asn1tools.parse_files(files)

parsed = parseFiles(files)
for f, p in zip(files, parsed):
  print(f)
  print(f"- {p}")
# Out:
# ../ETSI-ITS-ASN1/cam_en302637_2/CAM-PDU-Descriptions.asn
# - CAM-PDU-Descriptions
# ../ETSI-ITS-ASN1/cam_en302637_2/cdd/ITS-Container.asn
# - ITS-Container

# %%
# f = "CAM-PDU-Descriptions"
f = "ITS-Container"

for k, v in parsed[f].items():
  print(k)
  if isinstance(v, dict):
    for e in v:
      print(f"- {e}")
  else:
    print(f"- {v}")
# Out:
# imports
# types
# - ItsPduHeader
# - StationID
# - ReferencePosition
# - DeltaReferencePosition
# - Longitude
# - Latitude
# - Altitude
# - AltitudeValue
# - AltitudeConfidence
# - DeltaLongitude
# - DeltaLatitude
# - DeltaAltitude
# - PosConfidenceEllipse
# - PathPoint
# - PathDeltaTime
# - PtActivation
# - PtActivationType
# - PtActivationData
# - AccelerationControl
# - SemiAxisLength
# - CauseCode
# - CauseCodeType
# - SubCauseCodeType
# - TrafficConditionSubCauseCode
# - AccidentSubCauseCode
# - RoadworksSubCauseCode
# - HumanPresenceOnTheRoadSubCauseCode
# - WrongWayDrivingSubCauseCode
# - AdverseWeatherCondition-ExtremeWeatherConditionSubCauseCode
# - AdverseWeatherCondition-AdhesionSubCauseCode
# - AdverseWeatherCondition-VisibilitySubCauseCode
# - AdverseWeatherCondition-PrecipitationSubCauseCode
# - SlowVehicleSubCauseCode
# - StationaryVehicleSubCauseCode
# - HumanProblemSubCauseCode
# - EmergencyVehicleApproachingSubCauseCode
# - HazardousLocation-DangerousCurveSubCauseCode
# - HazardousLocation-SurfaceConditionSubCauseCode
# - HazardousLocation-ObstacleOnTheRoadSubCauseCode
# - HazardousLocation-AnimalOnTheRoadSubCauseCode
# - CollisionRiskSubCauseCode
# - SignalViolationSubCauseCode
# - RescueAndRecoveryWorkInProgressSubCauseCode
# - DangerousEndOfQueueSubCauseCode
# - DangerousSituationSubCauseCode
# - VehicleBreakdownSubCauseCode
# - PostCrashSubCauseCode
# - Curvature
# - CurvatureValue
# - CurvatureConfidence
# - CurvatureCalculationMode
# - Heading
# - HeadingValue
# - HeadingConfidence
# - LanePosition
# - ClosedLanes
# - HardShoulderStatus
# - DrivingLaneStatus
# - PerformanceClass
# - SpeedValue
# - SpeedConfidence
# - VehicleMass
# - Speed
# - DriveDirection
# - EmbarkationStatus
# - LongitudinalAcceleration
# - LongitudinalAccelerationValue
# - AccelerationConfidence
# - LateralAcceleration
# - LateralAccelerationValue
# - VerticalAcceleration
# - VerticalAccelerationValue
# - StationType
# - ExteriorLights
# - DangerousGoodsBasic
# - DangerousGoodsExtended
# - SpecialTransportType
# - LightBarSirenInUse
# - HeightLonCarr
# - PosLonCarr
# - PosPillar
# - PosCentMass
# - RequestResponseIndication
# - SpeedLimit
# - StationarySince
# - Temperature
# - TrafficRule
# - WheelBaseVehicle
# - TurningRadius
# - PosFrontAx
# - PositionOfOccupants
# - PositioningSolutionType
# - VehicleIdentification
# - WMInumber
# - VDS
# - EnergyStorageType
# - VehicleLength
# - VehicleLengthValue
# - VehicleLengthConfidenceIndication
# - VehicleWidth
# - PathHistory
# - EmergencyPriority
# - InformationQuality
# - RoadType
# - SteeringWheelAngle
# - SteeringWheelAngleValue
# - SteeringWheelAngleConfidence
# - TimestampIts
# - VehicleRole
# - YawRate
# - YawRateValue
# - YawRateConfidence
# - ProtectedZoneType
# - RelevanceDistance
# - RelevanceTrafficDirection
# - TransmissionInterval
# - ValidityDuration
# - ActionID
# - ItineraryPath
# - ProtectedCommunicationZone
# - Traces
# - NumberOfOccupants
# - SequenceNumber
# - PositionOfPillars
# - RestrictedTypes
# - EventHistory
# - EventPoint
# - ProtectedCommunicationZonesRSU
# - CenDsrcTollingZone
# - ProtectedZoneRadius
# - ProtectedZoneID
# - CenDsrcTollingZoneID
# - DigitalMap
# - OpeningDaysHours
# - PhoneNumber
# values
# object-classes
# object-sets
# extensibility-implied
# - False
# tags
# - AUTOMATIC

# %%
types = parsed[f]["types"]

# for k in ["CAM", "CoopAwareness", "CamParameters", "HighFrequencyContainer", "GenerationDeltaTime"]:
#   print(k)
#   print(f"  {types[k]}")

# %%
type_types = set([v["type"] for v in types.values()])
print(type_types)

member_keys = set()
for v in types.values():
  if "members" in v:
    for m in v["members"]:
      if m is None:
        continue
      member_keys.update(list(m.keys()))
print(member_keys)
# Out:
# {'ENUMERATED', 'IA5String', 'BIT STRING', 'UTF8String', 'ProtectedZoneID', 'NumericString', 'SEQUENCE', 'OCTET STRING', 'SEQUENCE OF', 'BOOLEAN', 'INTEGER'}
# {'type', 'named-numbers', 'size', 'optional', 'name', 'restricted-to'}

# %%
naive_types = {k: v for k, v in types.items() if v["type"] not in ("SEQUENCE", "SEQUENCE OF", "CHOICE")}
array_types = {k: v for k, v in types.items() if v["type"] == "SEQUENCE OF"}

print(list(naive_types.keys()))
print(list(array_types.keys()))
# Out:
# ['StationID', 'Longitude', 'Latitude', 'AltitudeValue', 'AltitudeConfidence', 'DeltaLongitude', 'DeltaLatitude', 'DeltaAltitude', 'PathDeltaTime', 'PtActivationType', 'PtActivationData', 'AccelerationControl', 'SemiAxisLength', 'CauseCodeType', 'SubCauseCodeType', 'TrafficConditionSubCauseCode', 'AccidentSubCauseCode', 'RoadworksSubCauseCode', 'HumanPresenceOnTheRoadSubCauseCode', 'WrongWayDrivingSubCauseCode', 'AdverseWeatherCondition-ExtremeWeatherConditionSubCauseCode', 'AdverseWeatherCondition-AdhesionSubCauseCode', 'AdverseWeatherCondition-VisibilitySubCauseCode', 'AdverseWeatherCondition-PrecipitationSubCauseCode', 'SlowVehicleSubCauseCode', 'StationaryVehicleSubCauseCode', 'HumanProblemSubCauseCode', 'EmergencyVehicleApproachingSubCauseCode', 'HazardousLocation-DangerousCurveSubCauseCode', 'HazardousLocation-SurfaceConditionSubCauseCode', 'HazardousLocation-ObstacleOnTheRoadSubCauseCode', 'HazardousLocation-AnimalOnTheRoadSubCauseCode', 'CollisionRiskSubCauseCode', 'SignalViolationSubCauseCode', 'RescueAndRecoveryWorkInProgressSubCauseCode', 'DangerousEndOfQueueSubCauseCode', 'DangerousSituationSubCauseCode', 'VehicleBreakdownSubCauseCode', 'PostCrashSubCauseCode', 'CurvatureValue', 'CurvatureConfidence', 'CurvatureCalculationMode', 'HeadingValue', 'HeadingConfidence', 'LanePosition', 'HardShoulderStatus', 'DrivingLaneStatus', 'PerformanceClass', 'SpeedValue', 'SpeedConfidence', 'VehicleMass', 'DriveDirection', 'EmbarkationStatus', 'LongitudinalAccelerationValue', 'AccelerationConfidence', 'LateralAccelerationValue', 'VerticalAccelerationValue', 'StationType', 'ExteriorLights', 'DangerousGoodsBasic', 'SpecialTransportType', 'LightBarSirenInUse', 'HeightLonCarr', 'PosLonCarr', 'PosPillar', 'PosCentMass', 'RequestResponseIndication', 'SpeedLimit', 'StationarySince', 'Temperature', 'TrafficRule', 'WheelBaseVehicle', 'TurningRadius', 'PosFrontAx', 'PositionOfOccupants', 'PositioningSolutionType', 'WMInumber', 'VDS', 'EnergyStorageType', 'VehicleLengthValue', 'VehicleLengthConfidenceIndication', 'VehicleWidth', 'EmergencyPriority', 'InformationQuality', 'RoadType', 'SteeringWheelAngleValue', 'SteeringWheelAngleConfidence', 'TimestampIts', 'VehicleRole', 'YawRateValue', 'YawRateConfidence', 'ProtectedZoneType', 'RelevanceDistance', 'RelevanceTrafficDirection', 'TransmissionInterval', 'ValidityDuration', 'NumberOfOccupants', 'SequenceNumber', 'ProtectedZoneRadius', 'ProtectedZoneID', 'CenDsrcTollingZoneID', 'OpeningDaysHours', 'PhoneNumber']
# ['PathHistory', 'ItineraryPath', 'Traces', 'PositionOfPillars', 'RestrictedTypes', 'EventHistory', 'ProtectedCommunicationZonesRSU', 'DigitalMap']

# %%
def ansType2RosMsg(type_name, type_info):

  if type_name in naive_types or type_name in array_types:
    return

  print(type_name)
  type_type = type_info["type"]
  if type_type == "SEQUENCE":
    for member in type_info["members"]:
      if member is None:
        continue
      if member["type"] in naive_types:
        member_name = member["name"]
        member = naive_types[member["type"]]
        member["name"] = member_name
      if member["type"] in array_types:
        member_name = member["name"]
        member_name = member["name"]
        member = array_types[member['type']]
        member["name"] = member_name
        member["type"] = f"{member['element']['type']}[]"
      lines = []
      comment_lines = []
      lines.append(f"  {member['type']} {member['name']}")
      if "values" in member:
        for val in member["values"]:
          if val is None:
            continue
          k, v = val
          lines.append(f"  INTEGER {member['name'].upper()}_{k.upper().replace('-', '_')} = {v}")
      if "named-numbers" in member:
        for k, v in member["named-numbers"].items():
          lines.append(f"  {member['type']} {member['name'].upper()}_{k.upper().replace('-', '_')} = {v}")
      for k, v in member.items():
        if k not in ("type", "name", "values", "named-numbers", "element"):
          comment_lines.append(f"{k}: {v}")
      print()
      comment_lines = [f"  # {cl}" for cl in comment_lines]
      for cl in comment_lines:
        print(cl)
      for l in lines:
        print(l)
  elif type_type == "CHOICE":
    # {'type': 'CHOICE', 'members': [{'type': 'BasicVehicleContainerHighFrequency', 'name': 'basicVehicleContainerHighFrequency'}, {'type': 'RSUContainerHighFrequency', 'name': 'rsuContainerHighFrequency'}, None]}
    pass
  else:
    raise ValueError(f"Unhandled type {type_type}")

for k, v in types.items():
  ansType2RosMsg(k, v)
  print("----------------------------------------")
# Out:
# ItsPduHeader
#
#   # restricted-to: [(0, 255)]
#   INTEGER protocolVersion
#
#   # restricted-to: [(0, 255)]
#   INTEGER messageID
#   INTEGER MESSAGEID_DENM = 1
#   INTEGER MESSAGEID_CAM = 2
#   INTEGER MESSAGEID_POI = 3
#   INTEGER MESSAGEID_SPATEM = 4
#   INTEGER MESSAGEID_MAPEM = 5
#   INTEGER MESSAGEID_IVIM = 6
#   INTEGER MESSAGEID_EV_RSR = 7
#   INTEGER MESSAGEID_TISTPGTRANSACTION = 8
#   INTEGER MESSAGEID_SREM = 9
#   INTEGER MESSAGEID_SSEM = 10
#   INTEGER MESSAGEID_EVCSN = 11
#   INTEGER MESSAGEID_SAEM = 12
#   INTEGER MESSAGEID_RTCMEM = 13
#
#   # restricted-to: [(0, 4294967295)]
#   INTEGER stationID
# ----------------------------------------
# ----------------------------------------
# ReferencePosition
#
#   # restricted-to: [(-900000000, 900000001)]
#   INTEGER latitude
#   INTEGER LATITUDE_ONEMICRODEGREENORTH = 10
#   INTEGER LATITUDE_ONEMICRODEGREESOUTH = -10
#   INTEGER LATITUDE_UNAVAILABLE = 900000001
#
#   # restricted-to: [(-1800000000, 1800000001)]
#   INTEGER longitude
#   INTEGER LONGITUDE_ONEMICRODEGREEEAST = 10
#   INTEGER LONGITUDE_ONEMICRODEGREEWEST = -10
#   INTEGER LONGITUDE_UNAVAILABLE = 1800000001
#
#   PosConfidenceEllipse positionConfidenceEllipse
#
#   Altitude altitude
# ----------------------------------------
# DeltaReferencePosition
#
#   # restricted-to: [(-131071, 131072)]
#   INTEGER deltaLatitude
#   INTEGER DELTALATITUDE_ONEMICRODEGREENORTH = 10
#   INTEGER DELTALATITUDE_ONEMICRODEGREESOUTH = -10
#   INTEGER DELTALATITUDE_UNAVAILABLE = 131072
#
#   # restricted-to: [(-131071, 131072)]
#   INTEGER deltaLongitude
#   INTEGER DELTALONGITUDE_ONEMICRODEGREEEAST = 10
#   INTEGER DELTALONGITUDE_ONEMICRODEGREEWEST = -10
#   INTEGER DELTALONGITUDE_UNAVAILABLE = 131072
#
#   # restricted-to: [(-12700, 12800)]
#   INTEGER deltaAltitude
#   INTEGER DELTAALTITUDE_ONECENTIMETERUP = 1
#   INTEGER DELTAALTITUDE_ONECENTIMETERDOWN = -1
#   INTEGER DELTAALTITUDE_UNAVAILABLE = 12800
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# Altitude
#
#   # restricted-to: [(-100000, 800001)]
#   INTEGER altitudeValue
#   INTEGER ALTITUDEVALUE_REFERENCEELLIPSOIDSURFACE = 0
#   INTEGER ALTITUDEVALUE_ONECENTIMETER = 1
#   INTEGER ALTITUDEVALUE_UNAVAILABLE = 800001
#
#   ENUMERATED altitudeConfidence
#   INTEGER ALTITUDECONFIDENCE_ALT_000_01 = 0
#   INTEGER ALTITUDECONFIDENCE_ALT_000_02 = 1
#   INTEGER ALTITUDECONFIDENCE_ALT_000_05 = 2
#   INTEGER ALTITUDECONFIDENCE_ALT_000_10 = 3
#   INTEGER ALTITUDECONFIDENCE_ALT_000_20 = 4
#   INTEGER ALTITUDECONFIDENCE_ALT_000_50 = 5
#   INTEGER ALTITUDECONFIDENCE_ALT_001_00 = 6
#   INTEGER ALTITUDECONFIDENCE_ALT_002_00 = 7
#   INTEGER ALTITUDECONFIDENCE_ALT_005_00 = 8
#   INTEGER ALTITUDECONFIDENCE_ALT_010_00 = 9
#   INTEGER ALTITUDECONFIDENCE_ALT_020_00 = 10
#   INTEGER ALTITUDECONFIDENCE_ALT_050_00 = 11
#   INTEGER ALTITUDECONFIDENCE_ALT_100_00 = 12
#   INTEGER ALTITUDECONFIDENCE_ALT_200_00 = 13
#   INTEGER ALTITUDECONFIDENCE_OUTOFRANGE = 14
#   INTEGER ALTITUDECONFIDENCE_UNAVAILABLE = 15
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# PosConfidenceEllipse
#
#   # restricted-to: [(0, 4095)]
#   INTEGER semiMajorConfidence
#   INTEGER SEMIMAJORCONFIDENCE_ONECENTIMETER = 1
#   INTEGER SEMIMAJORCONFIDENCE_OUTOFRANGE = 4094
#   INTEGER SEMIMAJORCONFIDENCE_UNAVAILABLE = 4095
#
#   # restricted-to: [(0, 4095)]
#   INTEGER semiMinorConfidence
#   INTEGER SEMIMINORCONFIDENCE_ONECENTIMETER = 1
#   INTEGER SEMIMINORCONFIDENCE_OUTOFRANGE = 4094
#   INTEGER SEMIMINORCONFIDENCE_UNAVAILABLE = 4095
#
#   # restricted-to: [(0, 3601)]
#   INTEGER semiMajorOrientation
#   INTEGER SEMIMAJORORIENTATION_WGS84NORTH = 0
#   INTEGER SEMIMAJORORIENTATION_WGS84EAST = 900
#   INTEGER SEMIMAJORORIENTATION_WGS84SOUTH = 1800
#   INTEGER SEMIMAJORORIENTATION_WGS84WEST = 2700
#   INTEGER SEMIMAJORORIENTATION_UNAVAILABLE = 3601
# ----------------------------------------
# PathPoint
#
#   DeltaReferencePosition pathPosition
#
#   # restricted-to: [(1, 65535), None]
#   INTEGER pathDeltaTime
#   INTEGER PATHDELTATIME_TENMILLISECONDSINPAST = 1
# ----------------------------------------
# ----------------------------------------
# PtActivation
#
#   # restricted-to: [(0, 255)]
#   INTEGER ptActivationType
#   INTEGER PTACTIVATIONTYPE_UNDEFINEDCODINGTYPE = 0
#   INTEGER PTACTIVATIONTYPE_R09_16CODINGTYPE = 1
#   INTEGER PTACTIVATIONTYPE_VDV_50149CODINGTYPE = 2
#
#   # size: [(1, 20)]
#   OCTET STRING ptActivationData
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# CauseCode
#
#   # restricted-to: [(0, 255)]
#   INTEGER causeCode
#   INTEGER CAUSECODE_RESERVED = 0
#   INTEGER CAUSECODE_TRAFFICCONDITION = 1
#   INTEGER CAUSECODE_ACCIDENT = 2
#   INTEGER CAUSECODE_ROADWORKS = 3
#   INTEGER CAUSECODE_IMPASSABILITY = 5
#   INTEGER CAUSECODE_ADVERSEWEATHERCONDITION_ADHESION = 6
#   INTEGER CAUSECODE_AQUAPLANNNING = 7
#   INTEGER CAUSECODE_HAZARDOUSLOCATION_SURFACECONDITION = 9
#   INTEGER CAUSECODE_HAZARDOUSLOCATION_OBSTACLEONTHEROAD = 10
#   INTEGER CAUSECODE_HAZARDOUSLOCATION_ANIMALONTHEROAD = 11
#   INTEGER CAUSECODE_HUMANPRESENCEONTHEROAD = 12
#   INTEGER CAUSECODE_WRONGWAYDRIVING = 14
#   INTEGER CAUSECODE_RESCUEANDRECOVERYWORKINPROGRESS = 15
#   INTEGER CAUSECODE_ADVERSEWEATHERCONDITION_EXTREMEWEATHERCONDITION = 17
#   INTEGER CAUSECODE_ADVERSEWEATHERCONDITION_VISIBILITY = 18
#   INTEGER CAUSECODE_ADVERSEWEATHERCONDITION_PRECIPITATION = 19
#   INTEGER CAUSECODE_SLOWVEHICLE = 26
#   INTEGER CAUSECODE_DANGEROUSENDOFQUEUE = 27
#   INTEGER CAUSECODE_VEHICLEBREAKDOWN = 91
#   INTEGER CAUSECODE_POSTCRASH = 92
#   INTEGER CAUSECODE_HUMANPROBLEM = 93
#   INTEGER CAUSECODE_STATIONARYVEHICLE = 94
#   INTEGER CAUSECODE_EMERGENCYVEHICLEAPPROACHING = 95
#   INTEGER CAUSECODE_HAZARDOUSLOCATION_DANGEROUSCURVE = 96
#   INTEGER CAUSECODE_COLLISIONRISK = 97
#   INTEGER CAUSECODE_SIGNALVIOLATION = 98
#   INTEGER CAUSECODE_DANGEROUSSITUATION = 99
#
#   # restricted-to: [(0, 255)]
#   INTEGER subCauseCode
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# Curvature
#
#   # restricted-to: [(-1023, 1023)]
#   INTEGER curvatureValue
#   INTEGER CURVATUREVALUE_STRAIGHT = 0
#   INTEGER CURVATUREVALUE_UNAVAILABLE = 1023
#
#   ENUMERATED curvatureConfidence
#   INTEGER CURVATURECONFIDENCE_ONEPERMETER_0_00002 = 0
#   INTEGER CURVATURECONFIDENCE_ONEPERMETER_0_0001 = 1
#   INTEGER CURVATURECONFIDENCE_ONEPERMETER_0_0005 = 2
#   INTEGER CURVATURECONFIDENCE_ONEPERMETER_0_002 = 3
#   INTEGER CURVATURECONFIDENCE_ONEPERMETER_0_01 = 4
#   INTEGER CURVATURECONFIDENCE_ONEPERMETER_0_1 = 5
#   INTEGER CURVATURECONFIDENCE_OUTOFRANGE = 6
#   INTEGER CURVATURECONFIDENCE_UNAVAILABLE = 7
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# Heading
#
#   # restricted-to: [(0, 3601)]
#   INTEGER headingValue
#   INTEGER HEADINGVALUE_WGS84NORTH = 0
#   INTEGER HEADINGVALUE_WGS84EAST = 900
#   INTEGER HEADINGVALUE_WGS84SOUTH = 1800
#   INTEGER HEADINGVALUE_WGS84WEST = 2700
#   INTEGER HEADINGVALUE_UNAVAILABLE = 3601
#
#   # restricted-to: [(1, 127)]
#   INTEGER headingConfidence
#   INTEGER HEADINGCONFIDENCE_EQUALORWITHINZEROPOINTONEDEGREE = 1
#   INTEGER HEADINGCONFIDENCE_EQUALORWITHINONEDEGREE = 10
#   INTEGER HEADINGCONFIDENCE_OUTOFRANGE = 126
#   INTEGER HEADINGCONFIDENCE_UNAVAILABLE = 127
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ClosedLanes
#
#   ENUMERATED innerhardShoulderStatus
#   INTEGER INNERHARDSHOULDERSTATUS_AVAILABLEFORSTOPPING = 0
#   INTEGER INNERHARDSHOULDERSTATUS_CLOSED = 1
#   INTEGER INNERHARDSHOULDERSTATUS_AVAILABLEFORDRIVING = 2
#
#   ENUMERATED outerhardShoulderStatus
#   INTEGER OUTERHARDSHOULDERSTATUS_AVAILABLEFORSTOPPING = 0
#   INTEGER OUTERHARDSHOULDERSTATUS_CLOSED = 1
#   INTEGER OUTERHARDSHOULDERSTATUS_AVAILABLEFORDRIVING = 2
#
#   # size: [(1, 13)]
#   BIT STRING drivingLaneStatus
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# Speed
#
#   # restricted-to: [(0, 16383)]
#   INTEGER speedValue
#   INTEGER SPEEDVALUE_STANDSTILL = 0
#   INTEGER SPEEDVALUE_ONECENTIMETERPERSEC = 1
#   INTEGER SPEEDVALUE_UNAVAILABLE = 16383
#
#   # restricted-to: [(1, 127)]
#   INTEGER speedConfidence
#   INTEGER SPEEDCONFIDENCE_EQUALORWITHINONECENTIMETERPERSEC = 1
#   INTEGER SPEEDCONFIDENCE_EQUALORWITHINONEMETERPERSEC = 100
#   INTEGER SPEEDCONFIDENCE_OUTOFRANGE = 126
#   INTEGER SPEEDCONFIDENCE_UNAVAILABLE = 127
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# LongitudinalAcceleration
#
#   # restricted-to: [(-160, 161)]
#   INTEGER longitudinalAccelerationValue
#   INTEGER LONGITUDINALACCELERATIONVALUE_POINTONEMETERPERSECSQUAREDFORWARD = 1
#   INTEGER LONGITUDINALACCELERATIONVALUE_POINTONEMETERPERSECSQUAREDBACKWARD = -1
#   INTEGER LONGITUDINALACCELERATIONVALUE_UNAVAILABLE = 161
#
#   # restricted-to: [(0, 102)]
#   INTEGER longitudinalAccelerationConfidence
#   INTEGER LONGITUDINALACCELERATIONCONFIDENCE_POINTONEMETERPERSECSQUARED = 1
#   INTEGER LONGITUDINALACCELERATIONCONFIDENCE_OUTOFRANGE = 101
#   INTEGER LONGITUDINALACCELERATIONCONFIDENCE_UNAVAILABLE = 102
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# LateralAcceleration
#
#   # restricted-to: [(-160, 161)]
#   INTEGER lateralAccelerationValue
#   INTEGER LATERALACCELERATIONVALUE_POINTONEMETERPERSECSQUAREDTORIGHT = -1
#   INTEGER LATERALACCELERATIONVALUE_POINTONEMETERPERSECSQUAREDTOLEFT = 1
#   INTEGER LATERALACCELERATIONVALUE_UNAVAILABLE = 161
#
#   # restricted-to: [(0, 102)]
#   INTEGER lateralAccelerationConfidence
#   INTEGER LATERALACCELERATIONCONFIDENCE_POINTONEMETERPERSECSQUARED = 1
#   INTEGER LATERALACCELERATIONCONFIDENCE_OUTOFRANGE = 101
#   INTEGER LATERALACCELERATIONCONFIDENCE_UNAVAILABLE = 102
# ----------------------------------------
# ----------------------------------------
# VerticalAcceleration
#
#   # restricted-to: [(-160, 161)]
#   INTEGER verticalAccelerationValue
#   INTEGER VERTICALACCELERATIONVALUE_POINTONEMETERPERSECSQUAREDUP = 1
#   INTEGER VERTICALACCELERATIONVALUE_POINTONEMETERPERSECSQUAREDDOWN = -1
#   INTEGER VERTICALACCELERATIONVALUE_UNAVAILABLE = 161
#
#   # restricted-to: [(0, 102)]
#   INTEGER verticalAccelerationConfidence
#   INTEGER VERTICALACCELERATIONCONFIDENCE_POINTONEMETERPERSECSQUARED = 1
#   INTEGER VERTICALACCELERATIONCONFIDENCE_OUTOFRANGE = 101
#   INTEGER VERTICALACCELERATIONCONFIDENCE_UNAVAILABLE = 102
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# DangerousGoodsExtended
#
#   ENUMERATED dangerousGoodsType
#   INTEGER DANGEROUSGOODSTYPE_EXPLOSIVES1 = 0
#   INTEGER DANGEROUSGOODSTYPE_EXPLOSIVES2 = 1
#   INTEGER DANGEROUSGOODSTYPE_EXPLOSIVES3 = 2
#   INTEGER DANGEROUSGOODSTYPE_EXPLOSIVES4 = 3
#   INTEGER DANGEROUSGOODSTYPE_EXPLOSIVES5 = 4
#   INTEGER DANGEROUSGOODSTYPE_EXPLOSIVES6 = 5
#   INTEGER DANGEROUSGOODSTYPE_FLAMMABLEGASES = 6
#   INTEGER DANGEROUSGOODSTYPE_NONFLAMMABLEGASES = 7
#   INTEGER DANGEROUSGOODSTYPE_TOXICGASES = 8
#   INTEGER DANGEROUSGOODSTYPE_FLAMMABLELIQUIDS = 9
#   INTEGER DANGEROUSGOODSTYPE_FLAMMABLESOLIDS = 10
#   INTEGER DANGEROUSGOODSTYPE_SUBSTANCESLIABLETOSPONTANEOUSCOMBUSTION = 11
#   INTEGER DANGEROUSGOODSTYPE_SUBSTANCESEMITTINGFLAMMABLEGASESUPONCONTACTWITHWATER = 12
#   INTEGER DANGEROUSGOODSTYPE_OXIDIZINGSUBSTANCES = 13
#   INTEGER DANGEROUSGOODSTYPE_ORGANICPEROXIDES = 14
#   INTEGER DANGEROUSGOODSTYPE_TOXICSUBSTANCES = 15
#   INTEGER DANGEROUSGOODSTYPE_INFECTIOUSSUBSTANCES = 16
#   INTEGER DANGEROUSGOODSTYPE_RADIOACTIVEMATERIAL = 17
#   INTEGER DANGEROUSGOODSTYPE_CORROSIVESUBSTANCES = 18
#   INTEGER DANGEROUSGOODSTYPE_MISCELLANEOUSDANGEROUSSUBSTANCES = 19
#
#   # restricted-to: [(0, 9999)]
#   INTEGER unNumber
#
#   BOOLEAN elevatedTemperature
#
#   BOOLEAN tunnelsRestricted
#
#   BOOLEAN limitedQuantity
#
#   # size: [(1, 24)]
#   # optional: True
#   IA5String emergencyActionCode
#
#   # size: [(1, 16)]
#   NumericString phoneNumber
#
#   # size: [(1, 24)]
#   # optional: True
#   UTF8String companyName
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# VehicleIdentification
#
#   # size: [(1, 3)]
#   IA5String wMInumber
#
#   # size: [6]
#   IA5String vDS
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# VehicleLength
#
#   # restricted-to: [(1, 1023)]
#   INTEGER vehicleLengthValue
#   INTEGER VEHICLELENGTHVALUE_TENCENTIMETERS = 1
#   INTEGER VEHICLELENGTHVALUE_OUTOFRANGE = 1022
#   INTEGER VEHICLELENGTHVALUE_UNAVAILABLE = 1023
#
#   ENUMERATED vehicleLengthConfidenceIndication
#   INTEGER VEHICLELENGTHCONFIDENCEINDICATION_NOTRAILERPRESENT = 0
#   INTEGER VEHICLELENGTHCONFIDENCEINDICATION_TRAILERPRESENTWITHKNOWNLENGTH = 1
#   INTEGER VEHICLELENGTHCONFIDENCEINDICATION_TRAILERPRESENTWITHUNKNOWNLENGTH = 2
#   INTEGER VEHICLELENGTHCONFIDENCEINDICATION_TRAILERPRESENCEISUNKNOWN = 3
#   INTEGER VEHICLELENGTHCONFIDENCEINDICATION_UNAVAILABLE = 4
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# SteeringWheelAngle
#
#   # restricted-to: [(-511, 512)]
#   INTEGER steeringWheelAngleValue
#   INTEGER STEERINGWHEELANGLEVALUE_STRAIGHT = 0
#   INTEGER STEERINGWHEELANGLEVALUE_ONEPOINTFIVEDEGREESTORIGHT = -1
#   INTEGER STEERINGWHEELANGLEVALUE_ONEPOINTFIVEDEGREESTOLEFT = 1
#   INTEGER STEERINGWHEELANGLEVALUE_UNAVAILABLE = 512
#
#   # restricted-to: [(1, 127)]
#   INTEGER steeringWheelAngleConfidence
#   INTEGER STEERINGWHEELANGLECONFIDENCE_EQUALORWITHINONEPOINTFIVEDEGREE = 1
#   INTEGER STEERINGWHEELANGLECONFIDENCE_OUTOFRANGE = 126
#   INTEGER STEERINGWHEELANGLECONFIDENCE_UNAVAILABLE = 127
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# YawRate
#
#   # restricted-to: [(-32766, 32767)]
#   INTEGER yawRateValue
#   INTEGER YAWRATEVALUE_STRAIGHT = 0
#   INTEGER YAWRATEVALUE_DEGSEC_000_01TORIGHT = -1
#   INTEGER YAWRATEVALUE_DEGSEC_000_01TOLEFT = 1
#   INTEGER YAWRATEVALUE_UNAVAILABLE = 32767
#
#   ENUMERATED yawRateConfidence
#   INTEGER YAWRATECONFIDENCE_DEGSEC_000_01 = 0
#   INTEGER YAWRATECONFIDENCE_DEGSEC_000_05 = 1
#   INTEGER YAWRATECONFIDENCE_DEGSEC_000_10 = 2
#   INTEGER YAWRATECONFIDENCE_DEGSEC_001_00 = 3
#   INTEGER YAWRATECONFIDENCE_DEGSEC_005_00 = 4
#   INTEGER YAWRATECONFIDENCE_DEGSEC_010_00 = 5
#   INTEGER YAWRATECONFIDENCE_DEGSEC_100_00 = 6
#   INTEGER YAWRATECONFIDENCE_OUTOFRANGE = 7
#   INTEGER YAWRATECONFIDENCE_UNAVAILABLE = 8
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ActionID
#
#   # restricted-to: [(0, 4294967295)]
#   INTEGER originatingStationID
#
#   # restricted-to: [(0, 65535)]
#   INTEGER sequenceNumber
# ----------------------------------------
# ----------------------------------------
# ProtectedCommunicationZone
#
#   ENUMERATED protectedZoneType
#   INTEGER PROTECTEDZONETYPE_PERMANENTCENDSRCTOLLING = 0
#   INTEGER PROTECTEDZONETYPE_TEMPORARYCENDSRCTOLLING = 1
#
#   # restricted-to: [(0, 4398046511103)]
#   INTEGER expiryTime
#   INTEGER EXPIRYTIME_UTCSTARTOF2004 = 0
#   INTEGER EXPIRYTIME_ONEMILLISECAFTERUTCSTARTOF2004 = 1
#
#   # restricted-to: [(-900000000, 900000001)]
#   INTEGER protectedZoneLatitude
#   INTEGER PROTECTEDZONELATITUDE_ONEMICRODEGREENORTH = 10
#   INTEGER PROTECTEDZONELATITUDE_ONEMICRODEGREESOUTH = -10
#   INTEGER PROTECTEDZONELATITUDE_UNAVAILABLE = 900000001
#
#   # restricted-to: [(-1800000000, 1800000001)]
#   INTEGER protectedZoneLongitude
#   INTEGER PROTECTEDZONELONGITUDE_ONEMICRODEGREEEAST = 10
#   INTEGER PROTECTEDZONELONGITUDE_ONEMICRODEGREEWEST = -10
#   INTEGER PROTECTEDZONELONGITUDE_UNAVAILABLE = 1800000001
#
#   # restricted-to: [(1, 255), None]
#   INTEGER protectedZoneRadius
#   INTEGER PROTECTEDZONERADIUS_ONEMETER = 1
#
#   # restricted-to: [(0, 134217727)]
#   INTEGER protectedZoneID
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# EventPoint
#
#   DeltaReferencePosition eventPosition
#
#   # restricted-to: [(1, 65535), None]
#   INTEGER eventDeltaTime
#   INTEGER EVENTDELTATIME_TENMILLISECONDSINPAST = 1
#
#   # restricted-to: [(0, 7)]
#   INTEGER informationQuality
#   INTEGER INFORMATIONQUALITY_UNAVAILABLE = 0
#   INTEGER INFORMATIONQUALITY_LOWEST = 1
#   INTEGER INFORMATIONQUALITY_HIGHEST = 7
# ----------------------------------------
# ----------------------------------------
# CenDsrcTollingZone
#
#   # restricted-to: [(-900000000, 900000001)]
#   INTEGER protectedZoneLatitude
#   INTEGER PROTECTEDZONELATITUDE_ONEMICRODEGREENORTH = 10
#   INTEGER PROTECTEDZONELATITUDE_ONEMICRODEGREESOUTH = -10
#   INTEGER PROTECTEDZONELATITUDE_UNAVAILABLE = 900000001
#
#   # restricted-to: [(-1800000000, 1800000001)]
#   INTEGER protectedZoneLongitude
#   INTEGER PROTECTEDZONELONGITUDE_ONEMICRODEGREEEAST = 10
#   INTEGER PROTECTEDZONELONGITUDE_ONEMICRODEGREEWEST = -10
#   INTEGER PROTECTEDZONELONGITUDE_UNAVAILABLE = 1800000001
#
#   ProtectedZoneID cenDsrcTollingZoneID
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
# ----------------------------------------
